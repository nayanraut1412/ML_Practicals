# %% [markdown]
# #   Aim: Implement Decission Tree in Python on a given dataset.

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %%
#data_no=pd.read_csv('Automobile.csv')
#df = pd.DataFrame()
df = pd.read_csv("Iris.csv")

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
X = df.iloc[:,1:5]
Y = df.iloc[:,-1]

# %%
X
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0              5.1           3.5            1.4           0.2
# 1              4.9           3.0            1.4           0.2
# 2              4.7           3.2            1.3           0.2
# 3              4.6           3.1            1.5           0.2
# 4              5.0           3.6            1.4           0.2
# ..             ...           ...            ...           ...
# 145            6.7           3.0            5.2           2.3
# 146            6.3           2.5            5.0           1.9
# 147            6.5           3.0            5.2           2.0
# 148            6.2           3.4            5.4           2.3
# 149            5.9           3.0            5.1           1.8
#
# [150 rows x 4 columns]

# %%
Y.shape
# Out:
# (150,)

# %%
X.shape
# Out:
# (150, 4)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.33, random_state=40)

# %%
Y_test.shape
# Out:
# (50,)

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()

# %%
dt.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier()

# %%
Y_pred = dt.predict(X_test)

# %%
dt.score(X_test,Y_test)
# Out:
# 1.0

# %%
import numpy as np
from sklearn.metrics import accuracy_score,f1_score,recall_score,precision_score

# %%
print('Accuracy: %.3f' % accuracy_score(Y_test, Y_pred))
print('Accuracy: %.3f' % f1_score(Y_test, Y_pred,average='micro'))
print('Accuracy: %.3f' % recall_score(Y_test, Y_pred, average='macro'))
print('Precision: %.3f' % precision_score(Y_test, Y_pred,average='macro'))
# Out:
# Accuracy: 1.000
# Accuracy: 1.000
# Accuracy: 1.000
# Precision: 1.000

# %%
from sklearn import tree
clf=tree.DecisionTreeClassifier()
clf=clf.fit(X_train,Y_train)

# %%
tree.plot_tree(clf)
# Out:
# [Text(0.4, 0.9166666666666666, 'x[2] <= 2.45\ngini = 0.666\nsamples = 100\nvalue = [32, 35, 33]'),
#  Text(0.3, 0.75, 'gini = 0.0\nsamples = 32\nvalue = [32, 0, 0]'),
#  Text(0.5, 0.75, 'x[2] <= 4.95\ngini = 0.5\nsamples = 68\nvalue = [0, 35, 33]'),
#  Text(0.2, 0.5833333333333334, 'x[3] <= 1.65\ngini = 0.108\nsamples = 35\nvalue = [0, 33, 2]'),
#  Text(0.1, 0.4166666666666667, 'gini = 0.0\nsamples = 32\nvalue = [0, 32, 0]'),
#  Text(0.3, 0.4166666666666667, 'x[0] <= 5.75\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2]'),
#  Text(0.2, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.4, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.8, 0.5833333333333334, 'x[3] <= 1.75\ngini = 0.114\nsamples = 33\nvalue = [0, 2, 31]'),
#  Text(0.7, 0.4166666666666667, 'x[3] <= 1.55\ngini = 0.444\nsamples = 6\nvalue = [0, 2, 4]'),
#  Text(0.6, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
# ...

# %%
import numpy as np
user_input = []
SepalLengthCm = 2.3
SepalWidthCm = 5.3
PetalLengthCm = 1.2
PetalWidthCm = 2.6
user_input.append([SepalLengthCm, SepalWidthCm, PetalLengthCm, PetalWidthCm])

user_input = np.array(user_input)

predicted_classes = dt.predict(user_input)

print(f"predicted class: {predicted_classes}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[98], line 13
#       9 user_input = np.array(user_input)
#      11 feature_names = ['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']
# ---> 13 predicted_classes = dt.predict(user_input, feature_names=feature_names)
#      15 print(f"predicted class: {predicted_classes}")
#
# TypeError: BaseDecisionTree.predict() got an unexpected keyword argument 'feature_names'

# %%
# import numpy as np

# user_input = []

# SepalLengthCm = float(input("Enter value for SepalLengthCm: "))
# SepalWidthCm = float(input("Enter value for SepalWidthCm: "))
# PetalLengthCm = float(input("Enter value for PetalLengthCm: "))
# PetalWidthCm = float(input("Enter value for PetalWidthCm: "))
# user_input.append([SepalLengthCm, SepalWidthCm, PetalLengthCm, PetalWidthCm])

# user_input = np.array(user_input)

# predicted_classes = dt.predict(user_input)

# print(predicted_classes)
